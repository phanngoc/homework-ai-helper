# %%
from firecrawl.firecrawl import FirecrawlApp

app = FirecrawlApp(api_key="fc-d8dc6df7ecdf47968d73fda7973670d5")

# Scrape a website:
# scrape_status = app.scrape_url(
#   'https://firecrawl.dev', 
#   params={'formats': ['markdown', 'html']}
# )
# print(scrape_status)

# Crawl a website:
crawl_status = app.crawl_url(
  'https://joblib.readthedocs.io/en/stable/', 
  params={
    'limit': 100, 
    'scrapeOptions': {'formats': ['markdown', 'html']}
  },
  poll_interval=30
)
print(crawl_status)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 13
#       3 app = FirecrawlApp(api_key="fc-d8dc6df7ecdf47968d73fda7973670d5")
#       5 # Scrape a website:
#       6 # scrape_status = app.scrape_url(
#       7 #   'https://firecrawl.dev',
#    (...)
#      11
#      12 # Crawl a website:
# ---> 13 crawl_status = app.crawl_url(
#      14   'https://joblib.readthedocs.io/en/stable/',
#      15   params={
#      16     'limit': 100,
#      17     'scrapeOptions': {'formats': ['markdown', 'html']}
#      18   },
#      19   poll_interval=30
#      20 )
#      21 print(crawl_status)
#
# File ~/Documents/projects/homework-ai-helper/.venv/lib/python3.12/site-packages/firecrawl/firecrawl.py:226, in FirecrawlApp.crawl_url(self, url, params, poll_interval, idempotency_key)
#     224     except:
#     225         raise Exception(f'Failed to parse Firecrawl response as JSON.')
# --> 226     return self._monitor_job_status(id, headers, poll_interval)
#     228 else:
#     229     self._handle_error(response, 'start crawl job')
#
# File ~/Documents/projects/homework-ai-helper/.venv/lib/python3.12/site-packages/firecrawl/firecrawl.py:905, in FirecrawlApp._monitor_job_status(self, id, headers, poll_interval)
#     903 elif status_data['status'] in ['active', 'paused', 'pending', 'queued', 'waiting', 'scraping']:
#     904     poll_interval=max(poll_interval,2)
# --> 905     time.sleep(poll_interval)  # Wait for the specified interval before checking again
#     906 else:
#     907     raise Exception(f'Crawl job failed or was stopped. Status: {status_data["status"]}')
#
# KeyboardInterrupt:
